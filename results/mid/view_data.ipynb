# %%
import pandas as pd

# %%
df_h1 = pd.read_csv('h1_min_nodes_alloc_germany_new.csv')
df_h2 = pd.read_csv('h2_min_residual_germany_new.csv')
df_h3 = pd.read_csv('h3_min_hops_germany_new.csv')

# %%
df_h1
# Out:
#    Application  MinNodes  MeanNodes  StdNodes  MeanTime  \
# 0         App0        14      15.71  0.791138  0.000390
# 1         App1        13      14.29  0.711266  0.000391
# 2         App2        15      16.88  0.886341  0.000405
# 3         App3        14      15.45  0.792149  0.000406
# 4         App4         3       4.01  0.479479  0.000177
# 5         App5        14      16.59  0.928386  0.000419
# 6         App6         5       5.59  0.491833  0.000191
# 7         App7        10      11.50  0.574456  0.000385
# 8         App8        11      12.35  0.726292  0.000329
# 9         App9        13      14.07  0.724638  0.000425
# 10       App10        13      15.24  0.873155  0.000404
# 11       App11         4       4.00  0.000000  0.000181
# 12       App12         8       9.55  0.554527  0.000277
# 13       App13        13      14.80  0.761577  0.000368
# 14       App14        17      19.42  1.124100  0.000523
# 15       App15         9      10.20  0.824621  0.000315
# ...

# %%
df_h2
# Out:
#    Application  MinNodes  MeanNodes  StdNodes  MeanTime  \
# 0         App0  0.636150   0.582083  0.024224  0.054637
# 1         App1  0.706897   0.581758  0.043312  0.037789
# 2         App2  0.611154   0.571260  0.025044  0.033665
# 3         App3  0.620251   0.551711  0.031941  0.057965
# 4         App4  0.645448   0.515953  0.054595  0.021597
# 5         App5  0.611400   0.556530  0.026335  0.061995
# 6         App6  0.703732   0.594112  0.044126  0.024310
# 7         App7  0.624069   0.568435  0.034208  0.041659
# 8         App8  0.705367   0.634074  0.036473  0.033509
# 9         App9  0.628111   0.564906  0.028051  0.037434
# 10       App10  0.678748   0.590853  0.034110  0.071501
# 11       App11  0.580212   0.495730  0.054174  0.031804
# 12       App12  0.709962   0.576345  0.055435  0.027886
# 13       App13  0.635536   0.575651  0.026878  0.059094
# 14       App14  0.623115   0.545237  0.039308  0.046610
# 15       App15  0.640999   0.516334  0.035580  0.037245
# ...

# %%
df_h3
# Out:
#    Application  MinHops  MeanMinHops  StdMinHops  MeanTime  \
# 0         App0     23.0    26.830000    1.985220  0.000571
# 1         App1     19.0    22.910000    2.608045  0.000555
# 2         App2     25.0    28.090000    1.588049  0.000569
# 3         App3     20.0    29.250000    3.453621  0.000597
# 4         App4      2.0     4.880000    1.498533  0.000244
# 5         App5     25.0    28.270000    2.101690  0.000650
# 6         App6      5.0     7.520000    1.717440  0.000483
# 7         App7     16.0    19.280000    2.218468  0.000507
# 8         App8     19.0    23.140000    1.490101  0.000614
# 9         App9     17.0    24.410000    3.501700  0.000571
# 10       App10     19.0    24.790000    3.374300  0.000505
# 11       App11      2.0     4.770000    1.310382  0.000199
# 12       App12     13.0    16.220000    2.105137  0.000404
# 13       App13     19.0    22.500000    2.805352  0.000554
# 14       App14     36.0    39.807018    1.317075  0.000619
# ...
